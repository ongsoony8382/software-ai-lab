# %%
print("Hello World")
# Out:
# Hello World

# %%
2+3
# Out:
# 5

# %%
19/3 #실수 나누기
# Out:
# 6.333333333333333

# %%
19//3 #정수 나누기 - 몫을 계산
# Out:
# 6

# %%
19 % 3 #나머지 연산자
# Out:
# 1

# %%
4 * 3.25 - 1 #정수 실수 혼합이면 결과는 실수
# Out:
# 12.0

# %%
radius = 3

# %%
pi = 3.14159

# %%
area = pi * radius ** 2

# %%
area
# Out:
# 28.27431

# %%
x, y, z = "오렌지", "바나나", "체리" # 시험

# %%
print(x)
print(y)
print(z)
# Out:
# 오렌지
# 바나나
# 체리

# %%
x = "홍길동"
print("내 이름은 " + x)
# Out:
# 내 이름은 홍길동
